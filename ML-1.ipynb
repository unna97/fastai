# %% [markdown]
# <a href="https://colab.research.google.com/github/unna97/fastai/blob/master/ML-1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kaggle
# !mkdir .kaggle
# !pip install pandas_summary
# Out:
# ...
# mkdir: cannot create directory ‘.kaggle’: File exists
# ...

# %%
from pandas_summary import DataFrameSummary

# %%
import json
token = {"username":"unnati97","key":"e066f821ad1de9e08721b767896ad7f4"}
with open('/content/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !cp /content/.kaggle/kaggle.json ~/.kaggle/kaggle.json
# !kaggle config set -n path -v{/content}

# %%
# !kaggle competitions download -c bluebook-for-bulldozers

# %%
# !mv /content/{/content}/competitions /content/

# %%
# !rm -r /content/{

# %%
# !unzip /content/competitions/bluebook-for-bulldozers/\*.zip

# %%
import pandas as pd
# !ls

# %%
Train = pd.read_csv("Train.csv",low_memory=False)

# %%
Train.head()
# Out:
#    SalesID  SalePrice  ...  Differential_Type  Steering_Controls
# 0  1139246      66000  ...           Standard       Conventional
# 1  1139248      57000  ...           Standard       Conventional
# 2  1139249      10000  ...                NaN                NaN
# 3  1139251      38500  ...                NaN                NaN
# 4  1139253      11000  ...                NaN                NaN
#
# [5 rows x 53 columns]
